# %%
import pandas as pd

# %%
bag=pd.Series(["pens","airplane"])
mobile=pd.Series(["Samsung","Nokia",'Iphone'])## series to pass vector
mobile
# Out:
# 0    Samsung
# 1      Nokia
# 2     Iphone
# dtype: object

# %%
dataFrame=pd.DataFrame({"electronics":mobile,"items":bag})## data Frame is for 2 d
dataFrame
# Out:
#   electronics     items
# 0     Samsung      pens
# 1       Nokia  airplane
# 2      Iphone       NaN

# %%
df=pd.read_csv('iris.csv')

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.to_csv('modified_iris.csv',index=False)### to drop index column while saving

# %% [markdown]
# # Attributes Without ()

# %%
df.columns ### properties of a variable
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# # Functions with ()

# %%
df.describe() ### functions that called on variable
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['SepalWidthCm'].sum()
# Out:
# 458.1

# %% [markdown]
# # index(.loc) & location (iloc)

# %%
df.iloc[3] ## location/position according to counting
# Out:
# Id                         4
# SepalLengthCm            4.6
# SepalWidthCm             3.1
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 3, dtype: object

# %%
df.loc[7] ## according to index
# Out:
# Id                         8
# SepalLengthCm            5.0
# SepalWidthCm             3.4
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 7, dtype: object

# %%
df.iloc[:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
df[df['Species']=="Iris-setosa"]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df[df['SepalLengthCm']>=7.0]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 102  103            7.1           3.0            5.9           2.1
# 105  106            7.6           3.0            6.6           2.1
# 107  108            7.3           2.9            6.3           1.8
# 109  110            7.2           3.6            6.1           2.5
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 122  123            7.7           2.8            6.7           2.0
# 125  126            7.2           3.2            6.0           1.8
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 135  136            7.7           3.0            6.1           2.3
#
#              Species
# ...

# %%
df['SepalLengthCm'].plot()
# Out:
# <Axes: >

# %%
df['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df["Species"].str.replace(["[\-]"],' ') ### changing object type for formatting
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df["Species"].str.replace(["[\-]"],' ')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
df["Species"]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 145   NaN
# 146   NaN
# 147   NaN
# 148   NaN
# 149   NaN
# Name: Species, Length: 150, dtype: float64

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df=pd.read_csv('modified_iris.csv')

# %%
df.head(15)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           NaN  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            NaN           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            NaN           0.2  Iris-setosa
# ...

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df["SepalLengthCm"].mean()
# Out:
# 5.848993288590604

# %%
df["SepalWidthCm"].mean()
# Out:
# 3.0540000000000003

# %% [markdown]
# # comparision

# %%
pd.crosstab(df['SepalLengthCm'],df['SepalWidthCm'])## for two columns
# Out:
# SepalWidthCm   2.5  2.8  2.9  3.2  3.4  3.8
# SepalLengthCm
# 0.046            0    0    0    0    1    0
# 0.050            0    0    0    0    1    0
# 0.051            0    0    0    0    0    1
# 0.054            0    0    0    0    1    0
# 0.057            0    0    1    0    0    0
# 0.063            1    0    0    0    0    0
# 0.067            1    0    0    0    0    0
# 0.069            0    0    0    1    0    0
# 0.073            0    0    1    0    0    0
# 0.074            0    1    0    0    0    0

# %%
df.groupby(['SepalWidthCm']).mean()
# Out:
# C:\Users\ammar\AppData\Local\Temp\ipykernel_12156\2632645835.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['SepalWidthCm']).mean()
#                       Id  SepalLengthCm  PetalLengthCm  PetalWidthCm
# SepalWidthCm
# 2.5            91.000000          0.065       5.350000          1.65
# 2.8           131.000000          0.074       6.100000          1.90
# 2.9           102.500000          0.065       5.250000          1.55
# 3.2           121.000000          0.069       5.700000          2.30
# 3.4            18.333333          0.050       1.566667          0.30
# 3.8            45.000000          0.051       1.900000          0.40

# %% [markdown]
# # Changing data

# %% [markdown]
# METHOD 1  : Filling out missing values

# %%
###df["PetalWidthCm"]=df["PetalWidthCm"].fillna(df["PetalWidthCm"].mean())### first method
df["PetalWidthCm"].fillna(df["PetalWidthCm"].mean(),inplace=True) # """ with inplace=true"""

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4      0.200000  Iris-setosa
# 1   2            4.9           3.0            1.4      0.200000  Iris-setosa
# 2   3            4.7           3.2            1.3      0.200000  Iris-setosa
# 3   4            4.6           3.1            1.5      1.205369  Iris-setosa
# 4   5            5.0           3.6            1.4      0.200000  Iris-setosa

# %% [markdown]
# # METHOD 2   Dropout missing val

# %%
df.dropna(inplace=True)

# %%
df.head(15)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4      0.200000  Iris-setosa
# 1    2            4.9           3.0            1.4      0.200000  Iris-setosa
# 2    3            4.7           3.2            1.3      0.200000  Iris-setosa
# 3    4            4.6           3.1            1.5      1.205369  Iris-setosa
# 4    5            5.0           3.6            1.4      0.200000  Iris-setosa
# 5    6            5.4           3.9            1.7      0.400000  Iris-setosa
# 6    7            4.6           3.4            1.4      0.300000  Iris-setosa
# 8    9            4.4           2.9            1.4      0.200000  Iris-setosa
# 9   10            4.9           3.1            1.5      0.100000  Iris-setosa
# 11  12            4.8           3.4            1.6      0.200000  Iris-setosa
# 12  13            4.8           3.0            1.4      0.100000  Iris-setosa
# ...

# %%
df.drop("Id",axis=1,inplace=True)

# %%
df["Colour"]=pd.Series(['Purple,Blue'])

# %%
for i in range(150):
    if df["Species"][i]=="Iris-setosa":
        df["Colour"][i]="Purple"
    else:
        df["Colour"][i]="blue"
# Out:
# C:\Users\ammar\AppData\Local\Temp\ipykernel_12156\3599258080.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Colour"][i]="Purple"
# C:\Users\ammar\AppData\Local\Temp\ipykernel_12156\3599258080.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Colour"][i]="blue"

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           NaN
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Colour
# 0       Iris-setosa  Purple
# 1       Iris-setosa  Purple
# 2       Iris-setosa  Purple
# 3       Iris-setosa  Purple
# ...

# %%
df['Species']=df['Species'].str.lower()

# %%
df
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   27          0.050           3.4            1.6           0.4
# 1   97          0.057           2.9            4.2           1.3
# 2  108          0.073           2.9            6.3           1.8
# 3  131          0.074           2.8            6.1           1.9
# 4    7          0.046           3.4            1.4           0.3
# 5   45          0.051           3.8            1.9           0.4
# 6  109          0.067           2.5            5.8           1.8
# 7  121          0.069           3.2            5.7           2.3
# 8   21          0.054           3.4            1.7           0.2
# 9   73          0.063           2.5            4.9           1.5
#
#            Species  Colour
# 0      iris-setosa  Purple
# 1  iris-versicolor    blue
# 2   iris-virginica    blue
# 3   iris-virginica    blue
# 4      iris-setosa  Purple
# 5      iris-setosa  Purple
# 6   iris-virginica    blue
# ...

# %% [markdown]
# # DATA MANIPULATION

# %% [markdown]
# ### FOR changing data / shuffling

# %%
df=df.sample(frac=0.25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 21 to 36
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10 non-null     int64
#  1   SepalLengthCm  10 non-null     float64
#  2   SepalWidthCm   10 non-null     float64
#  3   PetalLengthCm  10 non-null     float64
#  4   PetalWidthCm   10 non-null     float64
#  5   Species        10 non-null     object
#  6   Colour         10 non-null     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 640.0+ bytes

# %%
df.reset_index(drop=True, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10 non-null     int64
#  1   SepalLengthCm  10 non-null     float64
#  2   SepalWidthCm   10 non-null     float64
#  3   PetalLengthCm  10 non-null     float64
#  4   PetalWidthCm   10 non-null     float64
#  5   Species        10 non-null     object
#  6   Colour         10 non-null     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 688.0+ bytes

# %%
df
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   27            5.0           3.4            1.6           0.4
# 1   97            5.7           2.9            4.2           1.3
# 2  108            7.3           2.9            6.3           1.8
# 3  131            7.4           2.8            6.1           1.9
# 4    7            4.6           3.4            1.4           0.3
# 5   45            5.1           3.8            1.9           0.4
# 6  109            6.7           2.5            5.8           1.8
# 7  121            6.9           3.2            5.7           2.3
# 8   21            5.4           3.4            1.7           0.2
# 9   73            6.3           2.5            4.9           1.5
#
#            Species  Colour
# 0      Iris-setosa  Purple
# 1  Iris-versicolor    blue
# 2   Iris-virginica    blue
# 3   Iris-virginica    blue
# 4      Iris-setosa  Purple
# 5      Iris-setosa  Purple
# 6   Iris-virginica    blue
# ...

# %%
df['SepalLengthCm']=df['SepalLengthCm'].apply(lambda x:x/10)
df
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   27          0.050           3.4            1.6           0.4
# 1   97          0.057           2.9            4.2           1.3
# 2  108          0.073           2.9            6.3           1.8
# 3  131          0.074           2.8            6.1           1.9
# 4    7          0.046           3.4            1.4           0.3
# 5   45          0.051           3.8            1.9           0.4
# 6  109          0.067           2.5            5.8           1.8
# 7  121          0.069           3.2            5.7           2.3
# 8   21          0.054           3.4            1.7           0.2
# 9   73          0.063           2.5            4.9           1.5
#
#            Species  Colour
# 0      Iris-setosa  Purple
# 1  Iris-versicolor    blue
# 2   Iris-virginica    blue
# 3   Iris-virginica    blue
# 4      Iris-setosa  Purple
# 5      Iris-setosa  Purple
# 6   Iris-virginica    blue
# ...
